# %% [markdown]
# # <b>Provider Segmentation</b>
# STATEMENT: Here, our supply comes from service providers who decide to give their service booking on our platform. Unlike traditional service providers, these service are vary among each provider that are available to customers, therefore, service cannot be provide all year-round. Our service providers are people, with different earnings objectives and schedule constraints — leading to different <b>levels of availability</b> to service provider. <b>Understanding these differences is a key input into how we develop our products, campaigns, and operations.</b>

# %%
#!/usr/bin/env python3
# Christopher French
# 650510714
# availability
# 229496 Sec DS

# %% [markdown]
# ## <b>Provider Dataset</b>
#
# We'll use booking_raw.csv to simulate as a dataset for provider_segmentation first.

# %% [markdown]
# ### <b>Importing Dataset</b>

# %%
import pandas as pd
import numpy as np
import datetime
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# show all columns
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv('booking_raw.csv')
data
# Out:
#          booking_id  user_id  is_new_customer  user_place_id  \
# 0                23    31251                1              0
# 1                24        3                1              0
# 2                25        3                0              0
# 3                26        3                0              0
# 4                27        3                0              0
# ...             ...      ...              ...            ...
# 1135055  250401ZPCC   206782                0         296240
# 1135056  250508042C   232646                0         155725
# 1135057  250508ZGX6   232646                0         155725
# 1135058  2505085NC4   173130                0         104775
# 1135059  250508RUWQ   232646                0         155725
#
#                                  place_size              service_name  \
# 0        คอนโด 1 ห้องนอน (ไม่เกิน 40 ตร.ม.)         บริการทำความสะอาด
# 1        คอนโด 1 ห้องนอน (ไม่เกิน 50 ตร.ม.)         บริการทำความสะอาด
# 2        คอนโด 1 ห้องนอน (ไม่เกิน 50 ตร.ม.)         บริการทำความสะอาด
# 3        คอนโด 1 ห้องนอน (ไม่เกิน 40 ตร.ม.)         บริการทำความสะอาด
# 4        คอนโด 1 ห้องนอน (ไม่เกิน 50 ตร.ม.)         บริการทำความสะอาด
# ...                                     ...                       ...
# 1135055  คอนโด 1 ห้องนอน (ไม่เกิน 40 ตร.ม.)         บริการทำความสะอาด
# 1135056  คอนโด 1 ห้องนอน (ไม่เกิน 40 ตร.ม.)  บริการทำความสะอาดห้องน้ำ
# 1135057  คอนโด 1 ห้องนอน (ไม่เกิน 40 ตร.ม.)  บริการทำความสะอาดห้องน้ำ
# 1135058    บ้าน 1 ชั้น (ไม่เกิน 100 ตร.ม.)          บริการทำความสะอาด
# 1135059  คอนโด 1 ห้องนอน (ไม่เกิน 40 ตร.ม.)  บริการทำความสะอาดห้องน้ำ
#
#                 sub_service_name extra_service            province  \
# 0                            NaN           NaN           เชียงใหม่
# 1                            NaN           NaN           เชียงใหม่
# 2                            NaN           NaN           เชียงใหม่
# 3                            NaN           NaN           เชียงใหม่
# 4                            NaN           NaN           เชียงใหม่
# ...                          ...           ...                 ...
# 1135055                      NaN           NaN  กรุงเทพ และปริมณฑล
# 1135056  2 ห้องน้ำ (30-40 ตร.ม.)           NaN  กรุงเทพ และปริมณฑล
# 1135057  2 ห้องน้ำ (30-40 ตร.ม.)           NaN  กรุงเทพ และปริมณฑล
# 1135058                      NaN           NaN  กรุงเทพ และปริมณฑล
# 1135059  2 ห้องน้ำ (30-40 ตร.ม.)           NaN  กรุงเทพ และปริมณฑล
#
#            district         booking_date        cleaning_date  is_sameday  \
# 0               NaN  2016-03-23 08:50:10  2016-03-26 13:00:00           0
# 1               NaN  2016-03-24 21:14:38  2016-03-28 13:00:00           0
# 2               NaN  2016-03-26 20:56:23  2016-03-31 17:00:00           0
# 3               NaN  2016-03-26 20:58:36  2016-03-31 13:00:00           0
# 4               NaN  2016-03-26 21:04:26  2016-04-01 13:00:00           0
# ...             ...                  ...                  ...         ...
# 1135055  เขตพระโขนง  2025-05-08 15:07:28  2025-05-14 14:00:00           0
# 1135056    เขตวัฒนา  2025-05-08 15:08:58  2025-06-07 10:00:00           0
# 1135057    เขตวัฒนา  2025-05-08 15:09:45  2025-06-21 10:00:00           0
# 1135058    เขตบางแค  2025-05-08 15:10:08  2025-05-10 09:30:00           0
# 1135059    เขตวัฒนา  2025-05-08 15:10:48  2025-07-05 10:00:00           0
#
#          work_hour  additional_hour  total_price  discount_cost  \
# 0              2.0              0.0        400.0            0.0
# 1              2.5              0.0        500.0            0.0
# 2              2.5              0.0        500.0            0.0
# 3              2.0              0.0        400.0            0.0
# 4              2.5              0.0        500.0            0.0
# ...            ...              ...          ...            ...
# 1135055        2.0              0.0        520.0           26.0
# 1135056        2.0              0.0        500.0           30.0
# 1135057        2.0              0.0        500.0           30.0
# 1135058        2.0              0.0        520.0            0.0
# 1135059        2.0              0.0        500.0           30.0
#
#          credit_discount_cost promo_code  discount_pct  \
# 0                         0.0        NaN           NaN
# 1                         0.0        NaN           NaN
# 2                         0.0        NaN           NaN
# 3                         0.0        NaN           NaN
# 4                         0.0        NaN           NaN
# ...                       ...        ...           ...
# 1135055                   0.0     PACK_5           5.0
# 1135056                   0.0    Mayday5           6.0
# 1135057                   0.0    Mayday5           6.0
# 1135058                   0.0        NaN           NaN
# 1135059                   0.0    Mayday5           6.0
#
#                      booking_status cancel_reason  professional_id  \
# 0                         เสร็จสิ้น           NaN                8
# 1                         เสร็จสิ้น           NaN                5
# 2                         เสร็จสิ้น           NaN                7
# 3                         เสร็จสิ้น           NaN                7
# 4                         เสร็จสิ้น           NaN                8
# ...                             ...           ...              ...
# 1135055             รอเข้าให้บริการ           NaN            11886
# 1135056  ยังไม่มีคุณแม่บ้านกดรับงาน           NaN                0
# 1135057  ยังไม่มีคุณแม่บ้านกดรับงาน           NaN                0
# 1135058  ยังไม่มีคุณแม่บ้านกดรับงาน           NaN                0
# 1135059  ยังไม่มีคุณแม่บ้านกดรับงาน           NaN                0
#
#          selected_professional_id  is_new_professional  rating problem  \
# 0                               0                    1     4.0     NaN
# 1                               0                    1     NaN     NaN
# 2                               0                    0     5.0     NaN
# 3                               0                    0     5.0     NaN
# 4                               0                    0     5.0     NaN
# ...                           ...                  ...     ...     ...
# 1135055                         0                    0     NaN     NaN
# 1135056                     11292                    0     NaN     NaN
# 1135057                     11292                    0     NaN     NaN
# 1135058                     12414                    0     NaN     NaN
# 1135059                     11292                    0     NaN     NaN
#
#          is_claimed_booking
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 1135055                   0
# 1135056                   0
# 1135057                   0
# 1135058                   0
# 1135059                   0
#
# [1135060 rows x 28 columns]

# %%
data.service_name.unique()
# Out:
# array(['บริการทำความสะอาด', 'บริการรีดผ้า', 'บริการทำความสะอาดห้องน้ำ',
#        'บริการล้างแอร์'], dtype=object)

# %% [markdown]
# ### <b>Data Preprocessing & EDA</b>

# %%
data.shape
# Out:
# (1135060, 28)

# %%
data.columns
# Out:
# Index(['booking_id', 'user_id', 'is_new_customer', 'user_place_id',
#        'place_size', 'service_name', 'sub_service_name', 'extra_service',
#        'province', 'district', 'booking_date', 'cleaning_date', 'is_sameday',
#        'work_hour', 'additional_hour', 'total_price', 'discount_cost',
#        'credit_discount_cost', 'promo_code', 'discount_pct', 'booking_status',
#        'cancel_reason', 'professional_id', 'selected_professional_id',
#        'is_new_professional', 'rating', 'problem', 'is_claimed_booking'],
#       dtype='object')

# %%
data.dtypes
# Out:
# booking_id                   object
# user_id                       int64
# is_new_customer               int64
# user_place_id                 int64
# place_size                   object
# service_name                 object
# sub_service_name             object
# extra_service                object
# province                     object
# district                     object
# booking_date                 object
# cleaning_date                object
# is_sameday                    int64
# work_hour                   float64
# additional_hour             float64
# total_price                 float64
# discount_cost               float64
# credit_discount_cost        float64
# promo_code                   object
# discount_pct                float64
# booking_status               object
# cancel_reason                object
# professional_id               int64
# selected_professional_id      int64
# is_new_professional           int64
# rating                      float64
# problem                      object
# is_claimed_booking            int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1135060 entries, 0 to 1135059
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   booking_id                1135060 non-null  object
#  1   user_id                   1135060 non-null  int64
#  2   is_new_customer           1135060 non-null  int64
#  3   user_place_id             1135060 non-null  int64
#  4   place_size                1109181 non-null  object
#  5   service_name              1135060 non-null  object
#  6   sub_service_name          26417 non-null    object
#  7   extra_service             38345 non-null    object
#  8   province                  1135060 non-null  object
#  9   district                  1055083 non-null  object
#  10  booking_date              1135060 non-null  object
#  11  cleaning_date             1122742 non-null  object
#  12  is_sameday                1135060 non-null  int64
#  13  work_hour                 1135060 non-null  float64
#  14  additional_hour           1135060 non-null  float64
#  15  total_price               1135060 non-null  float64
#  16  discount_cost             1135060 non-null  float64
#  17  credit_discount_cost      1135060 non-null  float64
#  18  promo_code                627266 non-null   object
#  19  discount_pct              627266 non-null   float64
#  20  booking_status            1135060 non-null  object
#  21  cancel_reason             29611 non-null    object
#  22  professional_id           1135060 non-null  int64
#  23  selected_professional_id  1135060 non-null  int64
#  24  is_new_professional       1135060 non-null  int64
#  25  rating                    285103 non-null   float64
#  26  problem                   17128 non-null    object
#  27  is_claimed_booking        1135060 non-null  int64
# dtypes: float64(7), int64(8), object(13)
# memory usage: 242.5+ MB

# %%
data.nunique()
# Out:
# booking_id                  1134293
# user_id                      153632
# is_new_customer                   2
# user_place_id                222487
# place_size                        8
# service_name                      4
# sub_service_name                  7
# extra_service                     6
# province                          3
# district                        123
# booking_date                 936000
# cleaning_date                 73129
# is_sameday                        2
# work_hour                        23
# additional_hour                  15
# total_price                     427
# discount_cost                   936
# credit_discount_cost            581
# promo_code                    21399
# discount_pct                     23
# booking_status                    5
# cancel_reason                     7
# professional_id                7289
# selected_professional_id       5701
# is_new_professional               2
# rating                           10
# problem                          38
# is_claimed_booking                2
# dtype: int64
